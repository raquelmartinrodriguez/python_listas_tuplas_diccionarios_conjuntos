# %% [markdown]
# ## A continuación se detallarán una serie de ejercicios cortos cuyo objetivo es poner en practica los tipos de datos avanzados de Python: listas, tuplas, conjuntos y diccionarios.

# %% [markdown]
# ### 1.Trabajemos con listas y tuplas
# Crea una lista y una tupla que contenga strings (al menos 3 elementos). Temática libre, a poder ser, relacionado con la temática del master: pacientes, enfermedades, medicamentos, síntomas…
# Muestra la lista y la tupla

# %%
# Lista de medicamentos
medicamentos = ["Paracetamol", "Ibuprofeno", "Amoxicilina", "Omeprazol"]

# Tupla de síntomas
sintomas = ("Fiebre", "Tos", "Dolor de cabeza", "Fatiga")

print("Lista de medicamentos:", medicamentos)
print("Tupla de síntomas:", sintomas)
# Out:
# Lista de medicamentos: ['Paracetamol', 'Ibuprofeno', 'Amoxicilina', 'Omeprazol']
# Tupla de síntomas: ('Fiebre', 'Tos', 'Dolor de cabeza', 'Fatiga')

# %% [markdown]
# Muestra el 2º elemento de la lista y el penúltimo de la tupla

# %%
print(medicamentos[1])
print(sintomas[-2])
# Out:
# Ibuprofeno
# Dolor de cabeza

# %% [markdown]
# Modifica (si se puede) algún elemento de la lista y de la tupla. Y mostrar el resultado

# %%
medicamentos[1] = "Nolotil"
print(medicamentos)
#la tupla es inmutable, no se puede modificar
# Out:
# ['Paracetamol', 'Nolotil', 'Amoxicilina', 'Omeprazol']

# %% [markdown]
# Muestra el tamaño de la lista y de la tupla

# %%
print(len(medicamentos))
print(len(sintomas))
# Out:
# 4
# 4

# %% [markdown]
# Realiza una búsqueda de un elemento dentro de la lista y de la tupla. Mostrar si devuelve True o False

# %%
"Paracetamol" in medicamentos
# Out:
# True

# %%
"Ibuprofeno" in medicamentos
# Out:
# False

# %%
"hemorragia" in sintomas
# Out:
# False

# %% [markdown]
# Añade (si se puede) algún elemento a la lista y a la tupla. Mostrar de nuevo la lista y la tupla para verificar si se ha realizado correctamente la acción.

# %%
medicamentos.append("Ibuprofeno")
sintomas = sintomas + ("nauseas",)
print(medicamentos)
print(sintomas)
# Out:
# ['Paracetamol', 'Nolotil', 'Amoxicilina', 'Omeprazol', 'Ibuprofeno']
# ('Fiebre', 'Tos', 'Dolor de cabeza', 'Fatiga', 'nauseas')

# %% [markdown]
# Borra o elimina (si se puede) el contenido de la lista y de la tupla. Mosstrar de nuevo la lista y la tupla para verificar si se ha realizado correctamente la acción

# %%
medicamentos = []
print (medicamentos)
# Out:
# []

# %%
sintomas = ()
print(sintomas)
# Out:
# ()

# %% [markdown]
# ### 2. Trabajemos con sets y diccionarios

# %% [markdown]
# Crea una set y un diccionario que contengan strings (al menos 3 elementos en el caso del set y 3 conjuntos de clave:valor en el caso del diccionario). Temática libre, a poder ser, relacionado con la temática del master: pacientes, enfermedades, medicamentos, síntomas…
# Muestra el set y el diccionario

# %%
medicacion = {"analgesico", "antiinflamatorio", "antihemético", "anticoagulante"}
paciente = {
    "nombre": ["Pedro", "David", "Susana"],
    "edad": [58, 62, 54],
    "diabetes" : ["si", "no", "si"]
}
print(medicacion)
print(type(medicacion))
print(paciente)
print(type(paciente))
# Out:
# {'antiinflamatorio', 'antihemético', 'analgesico', 'anticoagulante'}
# <class 'set'>
# {'nombre': ['Pedro', 'David', 'Susana'], 'edad': [58, 62, 54], 'diabetes': ['si', 'no', 'si']}
# <class 'dict'>

# %% [markdown]
# Muestra (si se puede) el 2º elemento del set y el valor del primer clave-valor del diccionario

# %%
# en el set no puede acceder a los elementos de un conjunto set haciendo referencia a un índice, porque los conjuntos no están ordenados
# pero podemos recorrer los elementos del conjunto utilizando un bucle for
for x in medicacion: 
    print (x)
# Out:
# antiinflamatorio
# antihemético
# analgesico
# anticoagulante

# %%
print("Valor del primer clave-valor del diccionario")
for x, y in paciente.items():
    print (x,":", y)
    break #detiene el bucle en la primera vuelta
# Out:
# Valor del primer clave-valor del diccionario
# nombre : ['Pedro', 'David', 'Susana']

# %% [markdown]
# Modifica (si se puede) algún elemento del set o del diccionario. Y mostrar el resultado

# %%
paciente["nombre"][0] = "Lorena"
print (paciente)
# Out:
# {'nombre': ['Lorena', 'David', 'Susana'], 'edad': [58, 62, 54], 'diabetes': ['si', 'no', 'si']}

# %%
# no podemos modificar elementos del set, pero sí podemos agregar nuevos:
medicacion.add("antibiótico")
print (medicacion)
# Out:
# {'anticoagulante', 'antihemético', 'analgesico', 'antibiótico', 'antiinflamatorio'}

# %% [markdown]
# Muestra el tamaño del set y del diccionario

# %%
len(medicacion)
# Out:
# 5

# %%
len(paciente)
# Out:
# 3

# %% [markdown]
# Realiza una búsqueda de un elemento dentro del set y dentro del diccionario. Mostrar si devuelve True o False

# %%
"antibiótico" in medicacion
# Out:
# True

# %%
"edad" in paciente
# Out:
# True

# %%
"Lorena" in paciente["nombre"]
# Out:
# True

# %% [markdown]
# Añade (si se puede) algún elemento al set y algún clave-valor al diccionario. Mostrar de nuevo el set y el diccionario para verificar si se ha realizado correctamente la acción.

# %%
medicacion.add("antidepresivo")
print(medicacion)
# Out:
# {'anticoagulante', 'antihemético', 'analgesico', 'antibiótico', 'antiinflamatorio', 'antidepresivo'}

# %%
paciente["medicamento"] = ["Paracetamol", "Ibuprofeno", "Omeprazol"]
print(paciente)
# Out:
# {'nombre': ['Lorena', 'David', 'Susana'], 'edad': [58, 62, 54], 'diabetes': ['si', 'no', 'si'], 'medicamento': ['Paracetamol', 'Ibuprofeno', 'Omeprazol']}

# %% [markdown]
# Borra o elimina (si se puede) el contenido del set y del diccionario. Mostrar de nuevo el set y el diccionario para verificar si se ha realizado correctamente la acción

# %%
paciente.clear()
print(paciente)
# Out:
# {}

# %%
medicacion.clear()
print(medicacion)
# Out:
# set()

# %% [markdown]
# ### 3. Realizar un programa que pida al usuario 3 números (que pueden representar la temperatura de un paciente, por lo que deberán ser float) estos números se deberán introducir en una lista a medida que se van introduciendo. Cuando se haya finalizado la introducción de los datos, se mostrará el sumatorio de toda la lista y el promedio. Guardar el sumatorio en una variable que se llame "sumatorio" y el promedio en una variable llamada “promedio”.
# Ayuda: Existe una función llamada sum(lista) ¡Pruébalo!
# Para el promedio, en este caso sabemos que el número de elementos que ha introducido el usuario es 3, pero en otra ocasión podría ser diferente, por lo tanto, no hagáis referencia al número 3 en ningún sitio, es decir, no hagáis: sumatorio / 3. Investigar cómo podemos obtener el número de elementos de la lista de temperaturas.

# %%
temp1 = float(input("introduce tu temperatura a las 7:00"))
temp2 = float(input("introduce tu temperatura a las 14:00"))
temp3 = float(input("introduce tu temperatura a las 21:00"))

temperaturas = [temp1, temp2, temp3]

print("La suma de sus temperaturas es:")
sumatorio = sum(temperaturas)
print(sumatorio)

print("Su temperatura media es:")
promedio = sumatorio / len(temperaturas)
print (promedio)
# Out:
# introduce tu temperatura a las 7:00 36
# introduce tu temperatura a las 14:00 37
# introduce tu temperatura a las 21:00 38.5
# La suma de sus temperaturas es:
# 111.5
# El promedio de sus temperaturas es:
# 37.166666666666664

# %% [markdown]
# ### 4. Practiquemos con conjuntos:

# %% [markdown]
# Crea un conjunto llamado PacientesEstudioA que tenga los elementos Geli, Leticia, Carlos, Baltasar y Tobías
# Crea un conjunto llamado PacientesEstudioB que tenga los elementos Baltasar y Sandra

# %%
PacientesEstudioA = {"Geli", "Leticia", "Carlos", "Baltasar", "Tobías"}
PacientesEstudioB = {"Baltasar", "Sandra"}
print(type(PacientesEstudioA))
print(type(PacientesEstudioB))
# Out:
# <class 'set'>
# <class 'set'>

# %% [markdown]
# Borra a Tobías del conjunto PacientesEstudioA

# %%
PacientesEstudioA.remove("Tobías")
# Out:
# {'Leticia', 'Baltasar', 'Carlos', 'Geli'}

# %% [markdown]
# Añade a Pelayo al conjunto PacientesEstudioB

# %%
PacientesEstudioB.add("Pelayo")
# Out:
# {'Sandra', 'Baltasar', 'Pelayo'}

# %% [markdown]
# Imprime los conjuntos por pantalla

# %%
print(PacientesEstudioA)
print(PacientesEstudioB)
# Out:
# {'Leticia', 'Baltasar', 'Carlos', 'Geli'}
# {'Sandra', 'Baltasar', 'Pelayo'}

# %% [markdown]
# Imprime por pantalla los elementos que se encuentren en ambos conjuntos, es decir, que sean de ambos estudios.

# %%
ambosEstudios = PacientesEstudioA & PacientesEstudioB
print(ambosEstudios)
# Out:
# {'Baltasar'}

# %% [markdown]
# ###. 5. Practiquemos con diccionarios. Tenemos un diccionario que contiene un tratamiento para un paciente (el cual incluye una serie de medicamentos y cantidades que se le están proporcionando al paciente). Realicemos las tres siguientes tareas:
# Mostrar todo el tratamiento.

# %%
tratamiento = { 'id':[1,2,3],

'nombre':['AHKS', 'RGPS', 'PRCT'],

'cantidad': [1.2, 2.5, 0.36]

}
print(tratamiento)
# Out:
# {'id': [1, 2, 3], 'nombre': ['AHKS', 'RGPS', 'PRCT'], 'cantidad': [1.2, 2.5, 0.36]}

# %% [markdown]
# Subir la dosis a todos los medicamentos del tratamiento en un 50%

# %%
tratamiento["cantidad"][0] = round(tratamiento["cantidad"][0]*1.5, 2)
tratamiento["cantidad"][1] = round(tratamiento["cantidad"][1]*1.5, 2)
tratamiento["cantidad"][2] = round(tratamiento["cantidad"][2]*1.5, 2)
print(tratamiento)
# Out:
# {'id': [1, 2, 3], 'nombre': ['AHKS', 'RGPS', 'PRCT'], 'cantidad': [2.7, 5.62, 0.81]}

# %%
tratamiento = {
    'id': [1, 2, 3],
    'nombre': ['AHKS', 'RGPS', 'PRCT'],
    'cantidad': [1.2, 2.5, 0.36]
}

print("Tratamiento inicial:")

print(tratamiento['id'][0], "-", tratamiento['nombre'][0], "-", tratamiento['cantidad'][0], "ML")
print(tratamiento['id'][1], "-", tratamiento['nombre'][1], "-", tratamiento['cantidad'][1], "ML")
print(tratamiento['id'][2], "-", tratamiento['nombre'][2], "-", tratamiento['cantidad'][2], "ML")

# Subir dosis un 50 %
tratamiento['cantidad'][0] = tratamiento['cantidad'][0] * 1.5
tratamiento['cantidad'][1] = tratamiento['cantidad'][1] * 1.5
tratamiento['cantidad'][2] = tratamiento['cantidad'][2] * 1.5

print("\nTratamiento actualizado:")

print(tratamiento['id'][0], "-", tratamiento['nombre'][0], "-", round(tratamiento['cantidad'][0], 2), "ML")
print(tratamiento['id'][1], "-", tratamiento['nombre'][1], "-", round(tratamiento['cantidad'][1], 2), "ML")
print(tratamiento['id'][2], "-", tratamiento['nombre'][2], "-", round(tratamiento['cantidad'][2], 2), "ML")
# Out:
# Tratamiento inicial:
# 1 - AHKS - 1.2 ML
# 2 - RGPS - 2.5 ML
# 3 - PRCT - 0.36 ML
#
# Tratamiento actualizado:
# 1 - AHKS - 1.8 ML
# 2 - RGPS - 3.75 ML
# 3 - PRCT - 0.54 ML
